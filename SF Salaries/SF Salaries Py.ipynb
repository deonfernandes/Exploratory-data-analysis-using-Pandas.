# %%
import pandas as pd

# %%
df = pd.read_csv('SF Salaries data.csv')
# Out:
# C:\Users\visha\AppData\Local\Temp\ipykernel_15948\884256178.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('SF Salaries data.csv')

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# # Shape of the dataset (number of rows and columns)

# %%
df.shape
# Out:
# (148654, 13)

# %%
print('Number of rows - ', df.shape[0])
print('Number of columns - ', df.shape[1])
# Out:
# Number of rows -  148654
# Number of columns -  13

# %% [markdown]
# # Check Null values in the dataset

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# # Drop Notes and Status from the data

# %%
df = df.drop(['Notes', 'Status'], axis=1)

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %% [markdown]
# # Statistics

# %%
df.describe(include='all')
# Out:
#                    Id EmployeeName          JobTitle   BasePay  OvertimePay  \
# count   148654.000000       148654            148654  148049.0     148654.0
# unique            NaN       110811              2159  109900.0      66555.0
# top               NaN    Kevin Lee  Transit Operator       0.0          0.0
# freq              NaN           13              7036     875.0      66103.0
# mean     74327.500000          NaN               NaN       NaN          NaN
# std      42912.857795          NaN               NaN       NaN          NaN
# min          1.000000          NaN               NaN       NaN          NaN
# 25%      37164.250000          NaN               NaN       NaN          NaN
# 50%      74327.500000          NaN               NaN       NaN          NaN
# 75%     111490.750000          NaN               NaN       NaN          NaN
# max     148654.000000          NaN               NaN       NaN          NaN
#
# ...

# %% [markdown]
# # Number of unique Job titles

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# # Job title with 'Captain'

# %%
df[df['JobTitle'].str.contains('Captain', case=False)]
# Out:
#             Id        EmployeeName                               JobTitle  \
# 1            2        GARY JIMENEZ        CAPTAIN III (POLICE DEPARTMENT)
# 2            3      ALBERT PARDINI        CAPTAIN III (POLICE DEPARTMENT)
# 11          12    PATRICIA JACKSON        CAPTAIN III (POLICE DEPARTMENT)
# 17          18      SEBASTIAN WONG  CAPTAIN, EMERGENCYCY MEDICAL SERVICES
# 22          23       GEORGE GARCIA              CAPTAIN, FIRE SUPPRESSION
# ...        ...                 ...                                    ...
# 116604  116605   Gregory L Stewart              Captain, Fire Suppression
# 120867  120868     Michael J Moran                              Captain 3
# 122361  122362  Michael V Rolovich              Captain, Fire Suppression
# 126588  126589    Stephen M Tittel                              Captain 3
# 132232  132233     Jeanne M Seyler              Captain, Fire Suppression
#
#           BasePay OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
len(df[df['JobTitle'].str.contains('Captain', case=False)])
# Out:
# 552

# %% [markdown]
# # Employee names from Police Department

# %%
df[df['JobTitle'].str.contains('POLICE DEPARTMENT', case=False)]['EmployeeName']
# Out:
# 1                  GARY JIMENEZ
# 2                ALBERT PARDINI
# 11             PATRICIA JACKSON
# 15              RICHARD CORRIEA
# 28               DENISE SCHMITT
#                   ...
# 113903    Theresa J San Giacomo
# 113934       Ricardo S Castillo
# 114281          Alan M Callaway
# 114331          Paris C Deshong
# 123438           John A Haggett
# Name: EmployeeName, Length: 712, dtype: object

# %% [markdown]
# # Drop rows having 3 missing values

# %%
df.drop(df[df.isnull().sum(axis=1)==3].index,axis=0, inplace=True)

# %%
df[df.isnull().sum(axis=1)==3]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %% [markdown]
# # Job title of the employee Gary Altenberg

# %%
df. columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df[df['EmployeeName']== 'Gary Altenberg']['JobTitle']
# Out:
# 36159    Lieutenant, Fire Suppression
# Name: JobTitle, dtype: object

# %% [markdown]
# # Top 5 most common Jobs

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                6975
# Special Nurse                   4382
# Registered Nurse                3725
# Public Svc Aide-Public Works    2514
# Police Officer 3                2411
# Name: JobTitle, dtype: int64
